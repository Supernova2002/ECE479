# %% [markdown]
# Q: An a analyst fits an RF classifier where some of the features include seasonally adjusgted employment data. He aligns with January data the seasonally adjusted value of January, etc. What "sin" has he committed?
#
#
# A: Look-ahead bias, as the seasonal adjustments would not have been present for the month, i.e. the January data would not have been adjusted at the time it was released

# %% [markdown]
# Q: An analyst develops an ML algorithm where he generates a signal using closing
# prices, and executed at close. What’s the sin?
#
# A: Data mining/snooping, he was training on the test set (closing prices)

# %% [markdown]
# Q: There is a 98.51% correlation between total revenue generated by arcades and
# computer science doctorates awarded in the United States. As the number of
# doctorates is expected to grow, should we invest in arcades companies? If not,
# what’s the sin?
#
#
# A: No, it's storytelling. There's nothing to suggest a link between the two

# %% [markdown]
# Q: The Wall Street Journal has reported that September is the only month of the
# year that has negative average stock returns, looking back 20, 50, and 100 years.
# Should we sell stocks at the end of August? If not, what’s the sin?
#
# A: No, it's an outlier datapoint and there's no guarantee that this will hold, as it has only held for 3 years out of the last 100

# %% [markdown]
# Q: We download P/E ratios from Bloomberg, rank stocks every month, sell the top
# quartile, and buy the long quartile. Performance is amazing. What’s the sin?
#
# A: Survivorship bias is the sin
